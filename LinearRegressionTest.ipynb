# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
lr = LinearRegression()
dataSet = np.loadtxt(open('linear_regression_test.csv', "rb"), delimiter=",")

# %%
x = dataSet[:,0]
y = dataSet[:,1]

# %%
plt.plot(x,y, marker='o')
plt.title('Visualizing Relationship between X and Y')
plt.xlabel('X - Values')
plt.ylabel('Y - Values')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.model_selection import train_test_split

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x,y, test_size = 0.20, train_size = 0.80, random_state = 42, shuffle=True)

# %%
xTrain = xTrain.reshape(-1,1)

# %%
polyP = PolynomialFeatures(degree=2)

# %%
polyPTrain = polyP.fit_transform(xTrain)

# %%
lr.fit(polyPTrain, yTrain)
# Out:
# LinearRegression()

# %%
xTest = xTest.reshape(-1,1)
polyXTest = polyP.fit_transform(xTest)

# %%
predY = lr.predict(polyXTest)

# %%
plt.scatter(xTest, yTest, label='actual values')
plt.plot(xTest, predY, color= 'red', marker='_', label='predicted values')
plt.title('Visualizing actual values against predicted values')
plt.xlabel('X Values')
plt.ylabel('Y values')
plt.legend()
plt.show()

# %%
R2 = r2_score(yTest, predY)
print(R2)
# Out:
# 0.9558638968331364

# %%
MSE = mean_squared_error(yTest, predY)
print(MSE)
# Out:
# 0.8027410130882549
